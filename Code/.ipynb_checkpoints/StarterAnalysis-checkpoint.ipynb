# %%
import pandas as pd
import json
import requests
from pprint import pprint

# %%
#specify url
url = "https://data.cityofchicago.org/resource/4ijn-s7e5.json"

#retrieve json data and convert to pandas dataframe
res = requests.get(url).json()
#print("request returned")

df = pd.DataFrame.from_records(res)
df.head()
# Out:
#   inspection_id                dba_name                aka_name license_  \
# 0       2571104                  POCHOS                  POCHOS  2891234
# 1       2571084  ECUADORIAN FOOD MARKET  ECUADORIAN FOOD MARKET  2891168
# 2       2571092           HOWDY KOLACHE           HOWDY KOLACHE  2857104
# 3       2571099        INTERSECT COFFEE        INTERSECT COFFEE  2583887
# 4       2571086     VIET NAM RESTAURANT     VIET NAM RESTAURANT  2121019
#
#    facility_type             risk               address     city state    zip  \
# 0     Restaurant    Risk 1 (High)       1727 W 18TH ST   CHICAGO    IL  60608
# 1  Grocery Store     Risk 3 (Low)   5000 W DIVISION ST   CHICAGO    IL  60651
# 2     Restaurant    Risk 1 (High)  817 W FULTON MARKET   CHICAGO    IL  60607
# 3     Restaurant  Risk 2 (Medium)       1727 W 18TH ST   CHICAGO    IL  60608
# 4     Restaurant    Risk 1 (High)     1032 W ARGYLE ST   CHICAGO    IL  60640
#
# ...

# %%
#drop "aka_name" because it seems confusing or unneccessary . we can talk about it as a group later
df1 =df.drop(columns = ["aka_name"])
df1.head()
# Out:
#   inspection_id                dba_name license_  facility_type  \
# 0       2571104                  POCHOS  2891234     Restaurant
# 1       2571084  ECUADORIAN FOOD MARKET  2891168  Grocery Store
# 2       2571092           HOWDY KOLACHE  2857104     Restaurant
# 3       2571099        INTERSECT COFFEE  2583887     Restaurant
# 4       2571086     VIET NAM RESTAURANT  2121019     Restaurant
#
#               risk               address     city state    zip  \
# 0    Risk 1 (High)       1727 W 18TH ST   CHICAGO    IL  60608
# 1     Risk 3 (Low)   5000 W DIVISION ST   CHICAGO    IL  60651
# 2    Risk 1 (High)  817 W FULTON MARKET   CHICAGO    IL  60607
# 3  Risk 2 (Medium)       1727 W 18TH ST   CHICAGO    IL  60608
# 4    Risk 1 (High)     1032 W ARGYLE ST   CHICAGO    IL  60640
#
#            inspection_date  ...             results  \
# 0  2023-02-10T00:00:00.000  ...                Pass
# 1  2023-02-10T00:00:00.000  ...                Pass
# ...

# %%
df1.dtypes
# Out:
# inspection_id                  object
# dba_name                       object
# license_                       object
# facility_type                  object
# risk                           object
# address                        object
# city                           object
# state                          object
# zip                            object
# inspection_date                object
# inspection_type                object
# results                        object
# violations                     object
# latitude                       object
# longitude                      object
# location                       object
# :@computed_region_awaf_s7ux    object
# :@computed_region_6mkv_f3dw    object
# :@computed_region_vrxf_vc4k    object
# :@computed_region_bdys_3d7i    object
# :@computed_region_43wa_7qmu    object
# dtype: object
